# %% [markdown]
# <a href="https://colab.research.google.com/github/gbouras13/pharokka/blob/master/run_pharokka_and_phold_and_phynteny.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Pharokka + Phold + Phynteny
#
# [pharokka](https://github.com/gbouras13/pharokka) is a rapid standardised annotation tool for bacteriophage genomes and metagenomes. You can read more about pharokka in the [documentation](https://pharokka.readthedocs.io/).
#
# [phold](https://github.com/gbouras13/phold) is a sensitive annotation tool for bacteriophage genomes and metagenomes using protein structural homology. You can read more about phold in the [documentation](https://phold.readthedocs.io/).
#
# phold uses the [ProstT5](https://github.com/mheinzinger/ProstT5) protein language model to translate protein amino acid sequences to the 3Di token alphabet used by [Foldseek](https://github.com/steineggerlab/foldseek). Foldseek is then used to search these against a database of 803k protein structures mostly predicted using [Colabfold](https://github.com/sokrypton/ColabFold).
#
# [phyntney](https://github.com/susiegriggo/Phynteny_transformer) uses phage synteny (the conserved gene order across phages) with a hybrid transformer/LSTM architecture to assign hypothetical phage proteins to a PHROG category.
#
# The tools are best run sequentially, as Pharokka conducts extra annotation steps like tRNA, tmRNA, CRISPR and INPHARED searches that Phold lacks (for now at least). Pharokka will also (rarely) annotate CDS that Phold can miss. Phynteny can then help annotate remaining hypothetical proteins with a PHROG category.
#
# * **Before you start, please make sure you change the runtime to T4 GPU (or any other kind of GPU if you have $$$), otherwise Phold won't be installed properly**
# * To do this, go to the top toolbar, then to Runtime -> Change runtime type -> Hardware accelerator
#
# * To run the cells, press the play button on the left side
# * Cells 1, 2 and 3 install pharokka, phold and phyntney and download the databases/models.
# * Once they have been run, you can re-run Cell 4 (to run Pharokka), Cell 5 (to run Phold) and Cell 6 (to run Phynteny) as many times as you would like

# %%
#@title 1. Install miniforge

#@markdown This cell installs miniforge

# %%bash

set -e

PYTHON_VERSION="3.13"


echo "python version ${PYTHON_VERSION}"

if [ ! -f CONDA_READY ]; then
  echo "installing python"
  wget -qnc https://github.com/conda-forge/miniforge/releases/latest/download/Miniforge3-Linux-x86_64.sh
  bash Miniforge3-Linux-x86_64.sh -bfp /usr/local 2>&1 1>/dev/null
  conda config --set auto_update_conda false
  touch CONDA_READY
fi

pip install --upgrade matplotlib matplotlib-inline
# Out:
# python version 3.13
# installing python
# warning  libmamba [python-3.12.11-h9e4cc4f_0_cpython] The following files were already present in the environment:
#     - bin/python
# warning  libmamba [charset-normalizer-3.4.2-pyhd8ed1ab_0] The following files were already present in the environment:
#     - bin/normalizer
# warning  libmamba [distro-1.9.0-pyhd8ed1ab_1] The following files were already present in the environment:
#     - bin/distro
# warning  libmamba [jsonpointer-3.0.0-py312h7900ff3_1] The following files were already present in the environment:
#     - bin/jsonpointer
# warning  libmamba [wheel-0.45.1-pyhd8ed1ab_1] The following files were already present in the environment:
#     - bin/wheel
# warning  libmamba [jsonpatch-1.33-pyhd8ed1ab_1] The following files were already present in the environment:
#     - bin/jsondiff
#     - bin/jsonpatch
# warning  libmamba [pip-25.1.1-pyh8b19718_0] The following files were already present in the environment:
#     - bin/pip
#     - bin/pip3
# warning  libmamba [tqdm-4.67.1-pyhd8ed1ab_1] The following files were already present in the environment:
#     - bin/tqdm
# Collecting matplotlib
#   Downloading matplotlib-3.10.6-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (11 kB)
# Collecting matplotlib-inline
#   Downloading matplotlib_inline-0.1.7-py3-none-any.whl.metadata (3.9 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.59.2-cp312-cp312-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl.metadata (109 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.9-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (6.3 kB)
# Collecting numpy>=1.23 (from matplotlib)
#   Downloading numpy-2.3.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (62 kB)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/site-packages (from matplotlib) (25.0)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-11.3.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (9.0 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Downloading pyparsing-3.2.4-py3-none-any.whl.metadata (5.0 kB)
# Collecting python-dateutil>=2.7 (from matplotlib)
#   Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting traitlets (from matplotlib-inline)
#   Downloading traitlets-5.14.3-py3-none-any.whl.metadata (10 kB)
# Collecting six>=1.5 (from python-dateutil>=2.7->matplotlib)
#   Downloading six-1.17.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Downloading matplotlib-3.10.6-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 120.3 MB/s eta 0:00:00
# Downloading matplotlib_inline-0.1.7-py3-none-any.whl (9.9 kB)
# Downloading contourpy-1.3.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (362 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.59.2-cp312-cp312-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 117.7 MB/s eta 0:00:00
# Downloading kiwisolver-1.4.9-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 77.5 MB/s eta 0:00:00
# Downloading numpy-2.3.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 132.0 MB/s eta 0:00:00
# Downloading pillow-11.3.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (6.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 116.3 MB/s eta 0:00:00
# Downloading pyparsing-3.2.4-py3-none-any.whl (113 kB)
# Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
# Downloading six-1.17.0-py2.py3-none-any.whl (11 kB)
# Downloading traitlets-5.14.3-py3-none-any.whl (85 kB)
# Installing collected packages: traitlets, six, pyparsing, pillow, numpy, kiwisolver, fonttools, cycler, python-dateutil, matplotlib-inline, contourpy, matplotlib
#
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.59.2 kiwisolver-1.4.9 matplotlib-3.10.6 matplotlib-inline-0.1.7 numpy-2.3.3 pillow-11.3.0 pyparsing-3.2.4 python-dateutil-2.9.0.post0 six-1.17.0 traitlets-5.14.3

# %%
#@title 2. Install pharokka and phold and phynteny

#@markdown This cell installs pharokka and phold. It will take a few minutes. Please be patient

PHAROKKA_VERSION="1.8.0"
PHOLD_VERSION="1.0.0"
PHYNTENY_VERSION="0.1.2"

# add paths
import sys
sys.path.append("/usr/local/bin")

# Update environment variables for shell usage
import os
os.environ["PATH"] = "/usr/local/bin:" + os.environ["PATH"]

# create envs
# pharokka isn't compatible with Python 3.13 (Google Colab default)
# so it needs a separate env
from pathlib import Path
flag_file = Path("PHAROKKA_PHOLD_PHYNTENY_READY")
if not flag_file.exists():
  # !conda install -y -c bioconda phold==1.0.0 pharokka==1.8.0 pytorch=*=cuda* phynteny_transformer==0.1.2
  # Touch the flag file
  flag_file.touch()
# Out:
# Streaming output truncated to the last 5000 lines.
#
#
#
# mmseqs2-18.8cc5c     | 126.9 MB  | :  69% 0.6941515953044375/1 [00:47<00:01,  4.01s/it]
#
#
#
#
#
#
#
#
# libcufft-11.4.1.4    | 154.6 MB  | :  62% 0.6187572715720603/1 [00:47<00:01,  5.24s/it]
#
#
#
#
#
#
#
#
#
# mmseqs2-18.8cc5c     | 126.9 MB  | :  72% 0.7232182696287538/1 [00:47<00:01,  3.83s/it]
#
#
#
#
#
#
#
#
# libcufft-11.4.1.4    | 154.6 MB  | :  64% 0.6397834948177699/1 [00:47<00:01,  5.28s/it]
#
#
#
#
#
#
#
#
#
# mmseqs2-18.8cc5c     | 126.9 MB  | :  75% 0.7525312717015814/1 [00:47<00:00,  3.70s/it]
#
#
#
#
#
#
#
#
# libcufft-11.4.1.4    | 154.6 MB  | :  66% 0.6613151561222705/1 [00:47<00:01,  5.09s/it]
#
#
#
#
#
#
#
#
#
# mmseqs2-18.8cc5c     | 126.9 MB  | :  78% 0.7802431434090864/1 [00:47<00:00,  3.67s/it]
#
#
#
#
#
#
#
#
# libcufft-11.4.1.4    | 154.6 MB  | :  68% 0.6849696572736939/1 [00:47<00:01,  4.82s/it]
#
#
#
#
#
#
#
#
#
# mmseqs2-18.8cc5c     | 126.9 MB  | :  81% 0.8149753559491594/1 [00:47<00:00,  3.47s/it]
#
#
#
#
#
#
#
#
# libcufft-11.4.1.4    | 154.6 MB  | :  71% 0.7090285088721501/1 [00:47<00:01,  4.63s/it]
#
#
#
#
#
#
#
#
#
# mmseqs2-18.8cc5c     | 126.9 MB  | :  84% 0.8439188663992202/1 [00:47<00:00,  3.48s/it]
#
#
#
#
#
#
#
#
# libcufft-11.4.1.4    | 154.6 MB  | :  73% 0.7313688710707166/1 [00:47<00:01,  4.59s/it]
#
#
#
#
#
#
#
#
#
# mmseqs2-18.8cc5c     | 126.9 MB  | :  87% 0.8727392129750254/1 [00:47<00:00,  3.51s/it]
#
#
#
#
#
#
#
#
# libcufft-11.4.1.4    | 154.6 MB  | :  75% 0.7533048828222502/1 [00:47<00:01,  4.59s/it]
#
#
#
#
#
#
#
#
# libcufft-11.4.1.4    | 154.6 MB  | :  78% 0.7754430697973002/1 [00:48<00:01,  4.87s/it]
#
#
#
#
#
#
#
#
#
# mmseqs2-18.8cc5c     | 126.9 MB  | :  90% 0.9013132318023196/1 [00:48<00:00,  4.11s/it]
#
#
#
#
#
#
#
#
# libcufft-11.4.1.4    | 154.6 MB  | :  80% 0.7962671178194933/1 [00:48<00:01,  5.16s/it]
#
#
#
#
#
#
#
#
#
# mmseqs2-18.8cc5c     | 126.9 MB  | :  93% 0.9266849898989686/1 [00:48<00:00,  4.15s/it]
#
#
#
#
#
#
#
#
# libcufft-11.4.1.4    | 154.6 MB  | :  82% 0.8213368455355317/1 [00:48<00:00,  4.79s/it]
#
#
#
#
#
#
#
#
#
# mmseqs2-18.8cc5c     | 126.9 MB  | :  96% 0.9559979919717962/1 [00:48<00:00,  3.92s/it]
#
#
#
#
#
#
#
#
# libcufft-11.4.1.4    | 154.6 MB  | :  84% 0.8428685068400324/1 [00:48<00:00,  4.87s/it]
#
#
#
#
#
#
#
#
#
# mmseqs2-18.8cc5c     | 126.9 MB  | :  98% 0.9822318971882343/1 [00:48<00:00,  4.22s/it]
#
#
#
#
#
#
#
#
# libcufft-11.4.1.4    | 154.6 MB  | :  86% 0.8636925548622256/1 [00:48<00:00,  5.07s/it]
#
#
#
#
#
#
#
#
# libcufft-11.4.1.4    | 154.6 MB  | :  88% 0.8836068143785948/1 [00:48<00:00,  5.08s/it]
#
#
#
#
#
#
#
#
# libcufft-11.4.1.4    | 154.6 MB  | :  90% 0.904026511953755/1 [00:48<00:00,  5.03s/it]
#
#
#
#
#
#
#
#
# libcufft-11.4.1.4    | 154.6 MB  | :  93% 0.9312190795167161/1 [00:48<00:00,  4.56s/it]
#
#
#
#
#
#
#
#
# libcufft-11.4.1.4    | 154.6 MB  | :  95% 0.9533572664917661/1 [00:48<00:00,  4.66s/it]
#
#
#
#
#
#
#
#
# libcufft-11.4.1.4    | 154.6 MB  | :  97% 0.974990015408025/1 [00:49<00:00,  5.10s/it]
#
#
#
#
#
#
#
#
# libcufft-11.4.1.4    | 154.6 MB  | : 100% 0.9950053625361525/1 [00:49<00:00,  5.25s/it]
#
#
#
#
#
#
# libcusparse-12.5.10. | 199.2 MB  | : 100% 1.0/1 [00:51<00:00, 16.47s/it]
#
#
#
#
#
# nccl-2.27.7.1        | 203.8 MB  | : 100% 1.0/1 [00:51<00:00, 30.62s/it]
#
#
#
#
#
#
#
#
#
#
# openjdk-24.0.2       | 111.0 MB  | :   0% 0.00014075100523484809/1 [00:51<100:46:22, 362833.27s/it]
#
#
#
#
#
#
#
#
#
#
#
# triton-3.2.0         | 98.0 MB   | :   0% 0.00015944972095033669/1 [00:51<88:57:29, 320300.96s/it]
#
#
#
#
#
#
#
#
#
#
# openjdk-24.0.2       | 111.0 MB  | :   4% 0.040958542523340795/1 [00:51<14:00, 876.18s/it]
#
#
#
#
#
#
#
#
#
#
#
# triton-3.2.0         | 98.0 MB   | :   4% 0.038108483307130465/1 [00:51<15:06, 941.97s/it]
#
#
#
#
#
#
#
#
#
#
# openjdk-24.0.2       | 111.0 MB  | :   8% 0.08121333002050735/1 [00:51<05:36, 366.33s/it]
#
#
#
#
#
#
#
#
#
#
#
# triton-3.2.0         | 98.0 MB   | :   8% 0.07541971800950925/1 [00:51<06:05, 395.22s/it]
#
#
#
#
#
#
#
#
#
#
#
# triton-3.2.0         | 98.0 MB   | :  10% 0.10316396945486783/1 [00:51<03:40, 245.43s/it]
#
#
#
#
#
#
#
#
#
#
# openjdk-24.0.2       | 111.0 MB  | :  11% 0.11428981625069665/1 [00:51<03:14, 219.10s/it]
#
#
#
#
#
#
#
#
#
#
#
# triton-3.2.0         | 98.0 MB   | :  14% 0.1374456594591902/1 [00:51<02:07, 147.77s/it]
#
#
#
#
#
#
#
#
#
#
# openjdk-24.0.2       | 111.0 MB  | :  14% 0.14258076830290112/1 [00:51<02:06, 147.58s/it]
#
#
#
#
#
#
#
#
#
#
#
# triton-3.2.0         | 98.0 MB   | :  17% 0.1664655086721515/1 [00:51<01:23, 100.49s/it]
#
#
#
#
#
#
#
#
#
#
# openjdk-24.0.2       | 111.0 MB  | :  17% 0.1708717203551056/1 [00:51<01:24, 101.49s/it]
#
#
#
#
#
#
#
#
#
#
#
# triton-3.2.0         | 98.0 MB   | :  20% 0.19532590816416245/1 [00:51<00:56, 69.68s/it]
#
#
#
#
#
#
#
#
#
#
# openjdk-24.0.2       | 111.0 MB  | :  20% 0.20071093346489338/1 [00:51<00:55, 69.56s/it]
#
#
#
#
#
#
#
#
#
#
#
# triton-3.2.0         | 98.0 MB   | :  22% 0.22402685793522303/1 [00:51<00:38, 49.13s/it]
#
#
#
#
#
#
#
#
#
#
# openjdk-24.0.2       | 111.0 MB  | :  23% 0.23055014657468118/1 [00:51<00:37, 48.66s/it]
#
#
#
#
#
#
#
#
#
#
#
# triton-3.2.0         | 98.0 MB   | :  25% 0.25240890826438295/1 [00:51<00:26, 35.35s/it]
#
#
#
#
#
#
#
#
#
#
# openjdk-24.0.2       | 111.0 MB  | :  26% 0.26320437978916594/1 [00:52<00:24, 33.63s/it]
#
#
#
#
#
#
#
# libcusolver-11.7.5.8 | 195.7 MB  | : 100% 1.0/1 [00:52<00:00,  8.60s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-12.9.86   | 64.1 MB   | :   0% 0.0002438676165596114/1 [00:52<59:23:55, 213887.59s/it]
#
#
#
#
#
#
#
#
#
# mmseqs2-18.8cc5c     | 126.9 MB  | : 100% 1.0/1 [00:52<00:00,  4.22s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcurand-10.3.10.19 | 44.0 MB   | :   0% 0.00035492872277802955/1 [00:52<40:55:48, 147400.44s/it]
#
#
#
#
#
#
#
#
# libcufft-11.4.1.4    | 154.6 MB  | : 100% 1.0/1 [00:52<00:00,  5.25s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libllvm20-20.1.8     | 41.9 MB   | :   0% 0.00037247351605087137/1 [00:52<39:08:53, 140985.85s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libllvm20-20.1.8     | 41.9 MB   | :   0% 0.004842155708661327/1 [00:54<2:15:02, 8141.54s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-12.9.86   | 64.1 MB   | :   1% 0.0051212199477518395/1 [00:54<2:06:52, 7651.37s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcurand-10.3.10.19 | 44.0 MB   | :   1% 0.009938004237784827/1 [00:54<1:04:46, 3925.76s/it]
#
#
#
#
#
#
#
#
#
#
#
# triton-3.2.0         | 98.0 MB   | :  28% 0.27983426026784086/1 [00:54<00:36, 50.11s/it]
#
#
#
#
#
#
#
#
#
#
# openjdk-24.0.2       | 111.0 MB  | :  29% 0.29051007480472646/1 [00:54<00:34, 48.08s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libllvm20-20.1.8     | 41.9 MB   | :   3% 0.034640036992731035/1 [00:54<13:08, 817.27s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-12.9.86   | 64.1 MB   | :   6% 0.0556018165755914/1 [00:54<07:54, 502.63s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcurand-10.3.10.19 | 44.0 MB   | :   8% 0.084118107298393/1 [00:54<05:06, 334.76s/it]
#
#
#
#
#
#
#
#
#
#
#
# triton-3.2.0         | 98.0 MB   | :  31% 0.31140530501600755/1 [00:54<00:23, 34.73s/it]
#
#
#
#
#
#
#
#
#
#
# openjdk-24.0.2       | 111.0 MB  | :  32% 0.32288280600874153/1 [00:54<00:22, 33.47s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libllvm20-20.1.8     | 41.9 MB   | :   8% 0.07821943837068299/1 [00:54<04:22, 285.25s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-12.9.86   | 64.1 MB   | :  11% 0.10998429506838474/1 [00:54<03:04, 207.23s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcurand-10.3.10.19 | 44.0 MB   | :  17% 0.16752635715122993/1 [00:54<01:53, 136.25s/it]
#
#
#
#
#
#
#
#
#
#
#
# triton-3.2.0         | 98.0 MB   | :  34% 0.33914955646136613/1 [00:54<00:17, 25.77s/it]
#
#
#
#
#
#
#
#
#
#
# openjdk-24.0.2       | 111.0 MB  | :  35% 0.3461067218724914/1 [00:54<00:17, 26.27s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libllvm20-20.1.8     | 41.9 MB   | :  13% 0.13185562468200845/1 [00:54<01:56, 133.88s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-12.9.86   | 64.1 MB   | :  15% 0.15314886319943596/1 [00:54<01:45, 125.11s/it]
#
#
#
#
#
#
#
#
#
#
#
# triton-3.2.0         | 98.0 MB   | :  37% 0.3694450034419301/1 [00:54<00:11, 18.75s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcurand-10.3.10.19 | 44.0 MB   | :  23% 0.2257346676868268/1 [00:54<01:06, 86.33s/it]
#
#
#
#
#
#
#
#
#
#
# openjdk-24.0.2       | 111.0 MB  | :  38% 0.3751014289508702/1 [00:54<00:12, 19.24s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libllvm20-20.1.8     | 41.9 MB   | :  19% 0.19219633428224964/1 [00:54<00:58, 72.87s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-12.9.86   | 64.1 MB   | :  21% 0.21192095879030232/1 [00:54<00:56, 71.06s/it]
#
#
#
#
#
#
#
#
#
#
#
# triton-3.2.0         | 98.0 MB   | :  40% 0.40229164595769945/1 [00:54<00:08, 13.66s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcurand-10.3.10.19 | 44.0 MB   | :  29% 0.2928161962918744/1 [00:54<00:38, 54.09s/it]
#
#
#
#
#
#
#
#
#
#
# openjdk-24.0.2       | 111.0 MB  | :  40% 0.4029701279873701/1 [00:54<00:08, 14.61s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libllvm20-20.1.8     | 41.9 MB   | :  24% 0.2395004708207103/1 [00:54<00:37, 48.77s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-12.9.86   | 64.1 MB   | :  26% 0.2589874087863073/1 [00:54<00:35, 48.31s/it]
#
#
#
#
#
#
#
#
#
#
#
# triton-3.2.0         | 98.0 MB   | :  43% 0.4298764476821077/1 [00:54<00:06, 10.90s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcurand-10.3.10.19 | 44.0 MB   | :  35% 0.3510245068274712/1 [00:54<00:24, 37.33s/it]
#
#
#
#
#
#
#
#
#
#
# openjdk-24.0.2       | 111.0 MB  | :  43% 0.42844605993487755/1 [00:54<00:06, 11.67s/it]
#
#
#
# cusparselt-0.7.0.0   | 296.7 MB  | : 100% 1.0/1 [00:54<00:00, 75.07s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libllvm20-20.1.8     | 41.9 MB   | :  32% 0.31958227677164763/1 [00:54<00:18, 27.35s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-12.9.86   | 64.1 MB   | :  31% 0.3084925349479084/1 [00:54<00:22, 32.85s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcurand-10.3.10.19 | 44.0 MB   | :  43% 0.4312383981753059/1 [00:54<00:13, 23.38s/it]
#
#
#
#
#
#
#
#
#
#
# openjdk-24.0.2       | 111.0 MB  | :  45% 0.4536404898719154/1 [00:54<00:05,  9.50s/it]
#
#
#
#
#
#
#
#
#
#
#
# triton-3.2.0         | 98.0 MB   | :  46% 0.45698290024366495/1 [00:54<00:04,  8.99s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libllvm20-20.1.8     | 41.9 MB   | :  43% 0.4302069110387564/1 [00:55<00:08, 14.89s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-12.9.86   | 64.1 MB   | :  37% 0.36702076292221514/1 [00:55<00:13, 21.63s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcurand-10.3.10.19 | 44.0 MB   | :  51% 0.5086128597409163/1 [00:55<00:07, 15.70s/it]
#
#
#
#
#
#
#
#
#
#
#
# triton-3.2.0         | 98.0 MB   | :  49% 0.492061838852739/1 [00:55<00:03,  6.88s/it]
#
#
#
#
#
#
#
#
#
#
# openjdk-24.0.2       | 111.0 MB  | :  48% 0.47869416880371835/1 [00:55<00:04,  8.00s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libllvm20-20.1.8     | 41.9 MB   | :  50% 0.5017218261205237/1 [00:55<00:05, 10.82s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-12.9.86   | 64.1 MB   | :  42% 0.41579428623413744/1 [00:55<00:09, 15.87s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcurand-10.3.10.19 | 44.0 MB   | :  58% 0.5778239606826321/1 [00:55<00:04, 11.36s/it]
#
#
#
#
#
#
#
#
#
#
# openjdk-24.0.2       | 111.0 MB  | :  51% 0.5054368597983395/1 [00:55<00:03,  6.73s/it]
#
#
#
#
#
#
#
#
#
#
#
# triton-3.2.0         | 98.0 MB   | :  53% 0.5303297718808199/1 [00:55<00:02,  5.44s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libllvm20-20.1.8     | 41.9 MB   | :  58% 0.5840384731677664/1 [00:55<00:03,  7.64s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-12.9.86   | 64.1 MB   | :  47% 0.46578714762885776/1 [00:55<00:06, 11.64s/it]
#
#
#
#
#
#
#
#
#
#
#
# triton-3.2.0         | 98.0 MB   | :  56% 0.5649303613270429/1 [00:55<00:02,  4.65s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcurand-10.3.10.19 | 44.0 MB   | :  65% 0.6452604180104577/1 [00:55<00:02,  8.43s/it]
#
#
#
#
#
#
#
#
#
#
# openjdk-24.0.2       | 111.0 MB  | :  53% 0.5324610528034303/1 [00:55<00:02,  5.84s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libllvm20-20.1.8     | 41.9 MB   | :  66% 0.657415755829788/1 [00:55<00:02,  5.86s/it]
#
#
#
#
#
#
#
#
#
#
# openjdk-24.0.2       | 111.0 MB  | :  56% 0.5584999887718772/1 [00:55<00:02,  5.36s/it]
#
#
#
#
#
#
#
#
#
#
#
# triton-3.2.0         | 98.0 MB   | :  60% 0.5971392049590108/1 [00:55<00:01,  4.33s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcurand-10.3.10.19 | 44.0 MB   | :  71% 0.7109222317243932/1 [00:55<00:01,  6.48s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-12.9.86   | 64.1 MB   | :  51% 0.5130974652414224/1 [00:55<00:04,  9.06s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libllvm20-20.1.8     | 41.9 MB   | :  73% 0.72669582981525/1 [00:55<00:01,  4.65s/it]
#
#
#
#
#
#
#
#
#
#
# openjdk-24.0.2       | 111.0 MB  | :  58% 0.5834129166984453/1 [00:55<00:02,  5.00s/it]
#
#
#
#
#
#
#
#
#
#
#
# triton-3.2.0         | 98.0 MB   | :  63% 0.6282319005443265/1 [00:55<00:01,  4.11s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-12.9.86   | 64.1 MB   | :  56% 0.5569936362221525/1 [00:55<00:03,  7.27s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcurand-10.3.10.19 | 44.0 MB   | :  77% 0.7737446156561044/1 [00:55<00:01,  5.35s/it]
#
#
#
#
#
#
#
#
#
#
# openjdk-24.0.2       | 111.0 MB  | :  61% 0.6107186117140059/1 [00:55<00:01,  4.58s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libllvm20-20.1.8     | 41.9 MB   | :  79% 0.7937410627044069/1 [00:55<00:00,  3.89s/it]
#
#
#
#
#
#
#
#
#
#
#
# triton-3.2.0         | 98.0 MB   | :  66% 0.6583678978039402/1 [00:55<00:01,  3.90s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-12.9.86   | 64.1 MB   | :  61% 0.613083188030863/1 [00:55<00:02,  5.42s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcurand-10.3.10.19 | 44.0 MB   | :  84% 0.840826144261152/1 [00:55<00:00,  4.19s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libllvm20-20.1.8     | 41.9 MB   | :  87% 0.8730779216232425/1 [00:55<00:00,  3.05s/it]
#
#
#
#
#
#
#
#
#
#
#
# triton-3.2.0         | 98.0 MB   | :  69% 0.6889822442264049/1 [00:55<00:01,  3.72s/it]
#
#
#
#
#
#
#
#
#
#
# openjdk-24.0.2       | 111.0 MB  | :  64% 0.6363352946667482/1 [00:55<00:01,  4.58s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-12.9.86   | 64.1 MB   | :  66% 0.6611251084931065/1 [00:55<00:01,  4.47s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcurand-10.3.10.19 | 44.0 MB   | :  95% 0.9473047610945609/1 [00:55<00:00,  2.86s/it]
#
#
#
#
#
#
#
#
#
#
#
# triton-3.2.0         | 98.0 MB   | :  73% 0.7251773308821312/1 [00:55<00:00,  3.40s/it]
#
#
#
#
#
#
#
#
#
#
# openjdk-24.0.2       | 111.0 MB  | :  67% 0.6699747849178769/1 [00:55<00:01,  4.01s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libllvm20-20.1.8     | 41.9 MB   | :  94% 0.9397506809963485/1 [00:55<00:00,  2.69s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-12.9.86   | 64.1 MB   | :  71% 0.7111179698878268/1 [00:55<00:01,  3.76s/it]
#
#
#
#
#
#
#
#
#
#
#
# triton-3.2.0         | 98.0 MB   | :  76% 0.7572267247931489/1 [00:55<00:00,  3.35s/it]
#
#
#
#
#
#
#
#
#
#
# openjdk-24.0.2       | 111.0 MB  | :  70% 0.6971397289282025/1 [00:55<00:01,  4.05s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-12.9.86   | 64.1 MB   | :  76% 0.7576966846507126/1 [00:55<00:00,  3.31s/it]
#
#
#
#
#
#
#
#
#
#
#
# triton-3.2.0         | 98.0 MB   | :  80% 0.8005970488916405/1 [00:55<00:00,  3.00s/it]
#
#
#
#
#
#
#
#
#
#
# openjdk-24.0.2       | 111.0 MB  | :  74% 0.7390835284881873/1 [00:56<00:00,  3.41s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-12.9.86   | 64.1 MB   | :  82% 0.8198829268734136/1 [00:56<00:00,  2.74s/it]
#
#
#
#
#
#
#
#
#
#
# openjdk-24.0.2       | 111.0 MB  | :  78% 0.7753972878387781/1 [00:56<00:00,  3.24s/it]
#
#
#
#
#
#
#
#
#
#
#
# triton-3.2.0         | 98.0 MB   | :  84% 0.8355165377797642/1 [00:56<00:00,  3.13s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-12.9.86   | 64.1 MB   | :  89% 0.8869465214273067/1 [00:56<00:00,  2.31s/it]
#
#
#
#
#
#
#
#
#
#
# openjdk-24.0.2       | 111.0 MB  | :  82% 0.8179040914197022/1 [00:56<00:00,  2.95s/it]
#
#
#
#
#
#
#
#
#
#
#
# triton-3.2.0         | 98.0 MB   | :  87% 0.8721899735983417/1 [00:56<00:00,  3.04s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-12.9.86   | 64.1 MB   | :  94% 0.9418167351532193/1 [00:56<00:00,  2.21s/it]
#
#
#
#
#
#
#
#
#
#
# openjdk-24.0.2       | 111.0 MB  | :  86% 0.855203107806937/1 [00:56<00:00,  2.92s/it]
#
#
#
#
#
#
#
#
#
#
#
# triton-3.2.0         | 98.0 MB   | :  91% 0.9128496524406775/1 [00:56<00:00,  2.86s/it]
#
#
#
#
#
#
#
#
#
#
# openjdk-24.0.2       | 111.0 MB  | :  90% 0.8954578953041036/1 [00:56<00:00,  2.78s/it]
#
#
#
#
#
#
#
#
#
#
#
# triton-3.2.0         | 98.0 MB   | :  95% 0.954306579887765/1 [00:56<00:00,  2.72s/it]
#
#
#
#
#
#
#
#
#
#
# openjdk-24.0.2       | 111.0 MB  | :  93% 0.9334606667175125/1 [00:56<00:00,  2.76s/it]
#
#
#
#
#
#
#
#
#
#
#
# triton-3.2.0         | 98.0 MB   | :  99% 0.9917772643110941/1 [00:56<00:00,  2.78s/it]
#
#
#
#
#
#
#
#
#
#
# openjdk-24.0.2       | 111.0 MB  | :  97% 0.9706189320995124/1 [00:56<00:00,  2.78s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libllvm20-20.1.8     | 41.9 MB   | : 100% 1.0/1 [00:56<00:00,  2.69s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcurand-10.3.10.19 | 44.0 MB   | : 100% 1.0/1 [00:56<00:00,  2.86s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pillow-11.3.0        | 40.3 MB   | :   0% 0.00038798618216008085/1 [00:56<40:42:01, 146578.54s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libnvjitlink-12.9.86 | 29.1 MB   | :   0% 0.000536689564853647/1 [00:56<29:25:57, 106014.13s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pillow-11.3.0        | 40.3 MB   | :  12% 0.11678384083018434/1 [00:56<05:02, 342.12s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libnvjitlink-12.9.86 | 29.1 MB   | :  17% 0.16959390249375245/1 [00:57<03:15, 235.68s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pillow-11.3.0        | 40.3 MB   | :  23% 0.22813587511012753/1 [00:57<01:52, 145.92s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libnvjitlink-12.9.86 | 29.1 MB   | :  33% 0.33328421977411476/1 [00:57<01:06, 99.77s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libnvjitlink-12.9.86 | 29.1 MB   | :  45% 0.4459890283933806/1 [00:57<00:35, 63.91s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pillow-11.3.0        | 40.3 MB   | :  30% 0.30340519444918324/1 [00:57<01:05, 94.35s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pillow-11.3.0        | 40.3 MB   | :  39% 0.39458194725680223/1 [00:57<00:35, 58.69s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libnvjitlink-12.9.86 | 29.1 MB   | :  55% 0.5511801831046954/1 [00:57<00:19, 43.40s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pillow-11.3.0        | 40.3 MB   | :  47% 0.4710152251423382/1 [00:57<00:21, 40.69s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libnvjitlink-12.9.86 | 29.1 MB   | :  67% 0.6746187830210342/1 [00:57<00:09, 28.35s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pillow-11.3.0        | 40.3 MB   | :  55% 0.5458965582992338/1 [00:57<00:13, 28.68s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libnvjitlink-12.9.86 | 29.1 MB   | :  79% 0.7900070394645683/1 [00:57<00:04, 19.55s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pillow-11.3.0        | 40.3 MB   | :  67% 0.6731560260477403/1 [00:57<00:05, 16.81s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libnvjitlink-12.9.86 | 29.1 MB   | :  91% 0.9145190185106143/1 [00:57<00:01, 13.37s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pillow-11.3.0        | 40.3 MB   | :  79% 0.7860600050563238/1 [00:57<00:02, 11.23s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-12.9.86   | 64.1 MB   | : 100% 1.0/1 [00:57<00:00, 10.33s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-12.9.86   | 64.1 MB   | : 100% 1.0/1 [00:57<00:00, 10.33s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.6.0        | 27.1 MB   | :   0% 0.0005764487338147347/1 [00:57<27:54:21, 100519.52s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pillow-11.3.0        | 40.3 MB   | :  90% 0.8981880117005872/1 [00:57<00:00,  7.81s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.6.0        | 27.1 MB   | :  15% 0.14872377332420153/1 [00:58<03:53, 273.76s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pillow-11.3.0        | 40.3 MB   | : 100% 0.9990644190622082/1 [00:58<00:00,  5.82s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.6.0        | 27.1 MB   | :  29% 0.28880081564118204/1 [00:58<01:23, 117.09s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.6.0        | 27.1 MB   | :  44% 0.44386552503734567/1 [00:58<00:34, 61.70s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.6.0        | 27.1 MB   | :  63% 0.632364260994764/1 [00:58<00:12, 34.04s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.6.0        | 27.1 MB   | :  79% 0.7880054191247422/1 [00:58<00:04, 22.48s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libnvjitlink-12.9.86 | 29.1 MB   | : 100% 1.0/1 [00:58<00:00, 13.37s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.6.0        | 27.1 MB   | :  94% 0.9396114361180175/1 [00:58<00:00, 15.37s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
# triton-3.2.0         | 98.0 MB   | : 100% 1.0/1 [00:58<00:00,  2.78s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pillow-11.3.0        | 40.3 MB   | : 100% 1.0/1 [00:58<00:00,  5.82s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
# openjdk-24.0.2       | 111.0 MB  | : 100% 1.0/1 [00:59<00:00,  2.78s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.6.0        | 27.1 MB   | : 100% 1.0/1 [00:59<00:00, 15.37s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
# libcudnn-9.13.0.50   | 426.5 MB  | : 100% 1.0/1 [01:16<00:00, 16.59s/it]
# libcublas-12.9.1.4   | 446.0 MB  | : 100% 1.0/1 [01:26<00:00, 15.10s/it]
#
#
#
#
# libtorch-2.6.0       | 498.5 MB  | : 100% 1.0/1 [01:58<00:00, 25.95s/it]
#
#
#
#
#
#
# libcusparse-12.5.10. | 199.2 MB  | : 100% 1.0/1 [02:04<00:00, 16.47s/it]
#
#
#
#
#
# nccl-2.27.7.1        | 203.8 MB  | : 100% 1.0/1 [02:09<00:00, 30.62s/it]
#
#
#
#
#
#
#
# libcusolver-11.7.5.8 | 195.7 MB  | : 100% 1.0/1 [02:16<00:00,  8.60s/it]
#
#
#
#
#
#
#
#
#
# mmseqs2-18.8cc5c     | 126.9 MB  | : 100% 1.0/1 [02:51<00:00,  4.22s/it]
#
#
#
#
#
#
#
#
# libcufft-11.4.1.4    | 154.6 MB  | : 100% 1.0/1 [02:55<00:00,  5.25s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libllvm20-20.1.8     | 41.9 MB   | : 100% 1.0/1 [02:57<00:00,  2.69s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcurand-10.3.10.19 | 44.0 MB   | : 100% 1.0/1 [03:01<00:00,  2.86s/it]
#
#
# foldseek-10.941cd33  | 410.2 MB  | : 100% 1.0/1 [03:05<00:00, 277.19s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-12.9.86   | 64.1 MB   | : 100% 1.0/1 [03:06<00:00, 10.33s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libnvjitlink-12.9.86 | 29.1 MB   | : 100% 1.0/1 [03:07<00:00, 13.37s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pillow-11.3.0        | 40.3 MB   | : 100% 1.0/1 [03:09<00:00,  5.82s/it]
#
#
#
#
#
#
#
#
#
#
#
# triton-3.2.0         | 98.0 MB   | : 100% 1.0/1 [03:14<00:00,  2.78s/it]
#
#
#
#
#
#
#
#
#
#
# openjdk-24.0.2       | 111.0 MB  | : 100% 1.0/1 [03:15<00:00,  2.78s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.6.0        | 27.1 MB   | : 100% 1.0/1 [03:25<00:00, 15.37s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# done
# done
# - By downloading and using the cuSPARSELt conda package, you accept the terms
# and conditions of the NVIDIA cuSPARSELt Software License Agreement:
# https://docs.nvidia.com/cuda/cusparselt/license.html
#
# done

# %%
#@title 3. Download pharokka phold databases

#@markdown This cell downloads the pharokka then the phold database. It will take some time (10-15 minutes probably depending on Zenodo's traffic). Please be patient. Perhaps go for a walk or have a coffee or tea.


# %%time

print("Downloading pharokka database. This will take a few minutes. Please be patient :)")
# !install_databases.py -o pharokka_db


print("Downloading phold database. This will take a few minutes. Please be patient :)")
# !phold install -d phold_db -t 8 --foldseek_gpu


print("Downloading phynteny database. This will take a few minutes. Please be patient :)")
# !install_models -o  phynteny_models
# Out:
# Downloading pharokka database. This will take a few minutes. Please be patient :)
# 2025-09-16 03:03:39.314 | INFO     | databases:instantiate_install:113 - Checking Pharokka database installation in pharokka_db.
# 2025-09-16 03:03:39.314 | INFO     | databases:check_db_installation:236 - PHROGs Database file VERSION_1_8_0 is missing.
# 2025-09-16 03:03:39.314 | INFO     | databases:check_db_installation:243 - VFDB Databases are missing.
# 2025-09-16 03:03:39.314 | INFO     | databases:check_db_installation:250 - CARD Databases are missing.
# 2025-09-16 03:03:39.314 | INFO     | databases:check_db_installation:256 - PHROGs Annotation File is missing.
# 2025-09-16 03:03:39.314 | INFO     | databases:check_db_installation:262 - INPHARED Mash Annotation File is missing.
# 2025-09-16 03:03:39.314 | INFO     | databases:check_db_installation:268 - INPHARED Mash Sketch File is missing.
# 2025-09-16 03:03:39.314 | INFO     | databases:instantiate_install:118 - Some Databases are missing.
# 2025-09-16 03:03:39.314 | INFO     | databases:instantiate_install:123 - Downloading Pharokka Databases from https://zenodo.org/record/17110353/files/pharokka_v1.8.0_databases.tar.gz.
#
# 2025-09-16 03:06:33.816 | INFO     | databases:instantiate_install:134 - Database file download OK: a63c485241b900a11989bd1821bfbb09
# 2025-09-16 03:06:33.816 | INFO     | databases:instantiate_install:140 - Extracting DB tarball: file=pharokka_db/pharokka_v1.8.0_databases.tar.gz, output=pharokka_db
# Downloading phold database. This will take a few minutes. Please be patient :)
# 2025-09-16 03:07:05.008 | INFO     | phold:install:1260 - You have specified the phold_db directory to store the Phold database and ProstT5 model
# 2025-09-16 03:07:05.008 | INFO     | phold:install:1272 - Checking that the Rostlab/ProstT5_fp16 ProstT5 model is available in phold_db
# 2025-09-16 03:07:05.012 | INFO     | phold.features.predict_3Di:get_T5_model:125 - Using device: cpu
# 2025-09-16 03:07:05.013 | INFO     | phold.features.predict_3Di:get_T5_model:131 - Loading T5 from: phold_db/Rostlab/ProstT5_fp16
# 2025-09-16 03:07:05.013 | INFO     | phold.features.predict_3Di:get_T5_model:132 - If phold_db/Rostlab/ProstT5_fp16 is not found, it will be downloaded
# 2025-09-16 03:07:05.013 | WARNING  | phold.databases.db:check_prostT5_download:337 - Model file phold_db/models--Rostlab--ProstT5_fp16/refs/main does not exist.
# 2025-09-16 03:07:05.013 | WARNING  | phold.databases.db:check_prostT5_download:337 - Model file phold_db/models--Rostlab--ProstT5_fp16/blobs/2c19eb6e3b583f52d34b903b5978d3d30b6b7682 does not exist.
# 2025-09-16 03:07:05.013 | WARNING  | phold.databases.db:check_prostT5_download:337 - Model file phold_db/models--Rostlab--ProstT5_fp16/blobs/60fe6bb247c90b8545d7b73820cd796ce6dcbd59 does not exist.
# 2025-09-16 03:07:05.013 | WARNING  | phold.databases.db:check_prostT5_download:337 - Model file phold_db/models--Rostlab--ProstT5_fp16/blobs/6fc7be92c58e238f20a6cdea5a87b123a4ad35e2 does not exist.
# 2025-09-16 03:07:05.013 | WARNING  | phold.databases.db:check_prostT5_download:337 - Model file phold_db/models--Rostlab--ProstT5_fp16/blobs/74da7b4afcde53faa570114b530c726135bdfcdb813dec3abfb27f9d44db7324 does not exist.
# 2025-09-16 03:07:05.014 | WARNING  | phold.databases.db:check_prostT5_download:337 - Model file phold_db/models--Rostlab--ProstT5_fp16/blobs/b1a9ffcef73280cc57f090ad6446b4116b574b6c75d83ccc32778282f7f00855 does not exist.
# 2025-09-16 03:07:05.014 | WARNING  | phold.databases.db:check_prostT5_download:337 - Model file phold_db/models--Rostlab--ProstT5_fp16/blobs/e9322396e6e75ecf8da41a9527e24dfa4eeea505 does not exist.
# 2025-09-16 03:07:05.014 | INFO     | phold.features.predict_3Di:get_T5_model:142 - ProstT5 not found. Downloading ProstT5 from Hugging Face
# config.json: 100% 733/733 [00:00<00:00, 3.90MB/s]
# config.json: 100% 733/733 [00:00<00:00, 4.90MB/s]
# pytorch_model.bin: 100% 5.64G/5.64G [01:47<00:00, 52.5MB/s]
# model.safetensors:  19% 1.08G/5.64G [01:05<05:42, 13.3MB/s]
# tokenizer_config.json: 2.40kB [00:00, 399kB/s]
# model.safetensors:  20% 1.15G/5.64G [01:14<07:02, 10.6MB/s]
# model.safetensors:  29% 1.61G/5.64G [02:10<08:26, 7.95MB/s]
# spiece.model: 100% 238k/238k [00:55<00:00, 4.30kB/s]
#
# added_tokens.json: 100% 283/283 [00:00<00:00, 1.63MB/s]
#
# special_tokens_map.json: 2.20kB [00:00, 1.47MB/s]
# You are using the default legacy behaviour of the <class 'transformers.models.t5.tokenization_t5.T5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# 2025-09-16 03:11:07.883 | INFO     | phold.features.predict_3Di:get_T5_model:168 - Rostlab/ProstT5_fp16 loaded
# model.safetensors:  31% 1.75G/5.64G [02:12<04:26, 14.6MB/s]2025-09-16 03:11:08.617 | INFO     | phold:install:1283 - ProstT5 model downloaded
# 2025-09-16 03:11:08.618 | INFO     | phold.databases.db:install_database:145 - Checking Phold database installation in phold_db.
# 2025-09-16 03:11:08.618 | WARNING  | phold.databases.db:check_db_installation:411 - Phold Database file phold_db/acrs_plddt_over_70_metadata.tsv is missing
# 2025-09-16 03:11:08.619 | WARNING  | phold.databases.db:check_db_installation:420 - Phold Foldseek-GPU Database file phold_db/all_phold_structures_gpu is missing
# 2025-09-16 03:11:08.619 | INFO     | phold.databases.db:install_database:150 - Some Phold databases files are missing
# 2025-09-16 03:11:08.619 | INFO     | phold.databases.db:install_database:160 - Downloading Phold Search DB 1.36M from https://zenodo.org/records/16741548/files/phold_search_db_v_1_0_0.tar.gz
# 2025-09-16 03:11:08.642 | INFO     | phold.utils.external_tools:run_stream:55 - Started running aria2c --dir phold_db --out phold_search_db_v_1_0_0.tar.gz --max-connection-per-server=8 --allow-overwrite=true https://zenodo.org/records/16741548/files/phold_search_db_v_1_0_0.tar.gz ...
#
# 09/16 03:11:08 [NOTICE] Downloading 1 item(s)
# model.safetensors: 100% 5.64G/5.64G [03:22<00:00, 27.8MB/s]
# [#f0066d 0B/0B CN:1 DL:0B]
# [#f0066d 0B/1.7GiB(0%) CN:1 DL:0B]
# [#f0066d 1.0MiB/1.7GiB(0%) CN:5 DL:1.0MiB ETA:29m4s]
# [#f0066d 5.0MiB/1.7GiB(0%) CN:5 DL:2.5MiB ETA:11m43s]
# [#f0066d 9.3MiB/1.7GiB(0%) CN:5 DL:3.1MiB ETA:9m35s]
# [#f0066d 17MiB/1.7GiB(0%) CN:5 DL:2.9MiB ETA:10m9s]
# [#f0066d 36MiB/1.7GiB(2%) CN:5 DL:5.1MiB ETA:5m41s]
# [#f0066d 48MiB/1.7GiB(2%) CN:5 DL:5.9MiB ETA:4m58s]
# [#f0066d 49MiB/1.7GiB(2%) CN:5 DL:5.2MiB ETA:5m36s]
# [#f0066d 51MiB/1.7GiB(2%) CN:5 DL:5.0MiB ETA:5m45s]
# [#f0066d 88MiB/1.7GiB(4%) CN:5 DL:8.3MiB ETA:3m25s]
# [#f0066d 116MiB/1.7GiB(6%) CN:5 DL:10MiB ETA:2m36s]
# [#f0066d 144MiB/1.7GiB(7%) CN:5 DL:16MiB ETA:1m43s]
# [#f0066d 173MiB/1.7GiB(9%) CN:5 DL:17MiB ETA:1m33s]
# [#f0066d 202MiB/1.7GiB(11%) CN:5 DL:18MiB ETA:1m27s]
# [#f0066d 236MiB/1.7GiB(13%) CN:5 DL:21MiB ETA:1m14s]
# [#f0066d 265MiB/1.7GiB(14%) CN:5 DL:21MiB ETA:1m10s]
# [#f0066d 291MiB/1.7GiB(16%) CN:5 DL:25MiB ETA:58s]
# [#f0066d 294MiB/1.7GiB(16%) CN:5 DL:22MiB ETA:1m8s]
# [#f0066d 321MiB/1.7GiB(17%) CN:5 DL:22MiB ETA:1m7s]
# [#f0066d 328MiB/1.7GiB(18%) CN:5 DL:18MiB ETA:1m18s]
# [#f0066d 331MiB/1.7GiB(18%) CN:5 DL:14MiB ETA:1m42s]
# [#f0066d 332MiB/1.7GiB(18%) CN:5 DL:10MiB ETA:2m23s]
# [#f0066d 351MiB/1.7GiB(19%) CN:5 DL:9.1MiB ETA:2m38s]
# [#f0066d 384MiB/1.7GiB(21%) CN:5 DL:11MiB ETA:2m7s]
# [#f0066d 396MiB/1.7GiB(21%) CN:5 DL:11MiB ETA:2m5s]
# [#f0066d 396MiB/1.7GiB(21%) CN:5 DL:10MiB ETA:2m10s]
# [#f0066d 419MiB/1.7GiB(23%) CN:5 DL:10MiB ETA:2m13s]
# [#f0066d 432MiB/1.7GiB(23%) CN:5 DL:11MiB ETA:1m59s]
# [#f0066d 449MiB/1.7GiB(24%) CN:5 DL:12MiB ETA:1m52s]
# [#f0066d 470MiB/1.7GiB(26%) CN:5 DL:14MiB ETA:1m32s]
# [#f0066d 483MiB/1.7GiB(26%) CN:5 DL:16MiB ETA:1m20s]
# [#f0066d 498MiB/1.7GiB(27%) CN:5 DL:15MiB ETA:1m22s]
# [#f0066d 513MiB/1.7GiB(28%) CN:5 DL:14MiB ETA:1m32s]
# [#f0066d 522MiB/1.7GiB(28%) CN:5 DL:14MiB ETA:1m30s]
# [#f0066d 523MiB/1.7GiB(28%) CN:5 DL:13MiB ETA:1m37s]
# [#f0066d 525MiB/1.7GiB(28%) CN:5 DL:10MiB ETA:2m2s]
# [#f0066d 554MiB/1.7GiB(30%) CN:5 DL:10MiB ETA:2m3s]
# [#f0066d 555MiB/1.7GiB(30%) CN:5 DL:6.6MiB ETA:3m8s]
# [#f0066d 557MiB/1.7GiB(30%) CN:5 DL:4.1MiB ETA:5m4s]
# [#f0066d 584MiB/1.7GiB(32%) CN:5 DL:6.7MiB ETA:3m]
# [#f0066d 594MiB/1.7GiB(32%) CN:5 DL:7.9MiB ETA:2m33s]
# [#f0066d 595MiB/1.7GiB(32%) CN:5 DL:4.9MiB ETA:4m7s]
# [#f0066d 630MiB/1.7GiB(34%) CN:5 DL:7.9MiB ETA:2m28s]
# [#f0066d 648MiB/1.7GiB(35%) CN:5 DL:11MiB ETA:1m37s]
# [#f0066d 664MiB/1.7GiB(36%) CN:5 DL:12MiB ETA:1m31s]
#  *** Download Progress Summary as of Tue Sep 16 03:12:19 2025 ***
# ===============================================================================
# [#f0066d 673MiB/1.7GiB(37%) CN:5 DL:0B]
# FILE: phold_db/phold_search_db_v_1_0_0.tar.gz
# -------------------------------------------------------------------------------
#
# [#f0066d 673MiB/1.7GiB(37%) CN:5 DL:0B]
# [#f0066d 696MiB/1.7GiB(38%) CN:5 DL:23MiB ETA:48s]
# [#f0066d 711MiB/1.7GiB(39%) CN:5 DL:18MiB ETA:57s]
# [#f0066d 719MiB/1.7GiB(39%) CN:5 DL:15MiB ETA:1m10s]
# [#f0066d 731MiB/1.7GiB(40%) CN:5 DL:14MiB ETA:1m14s]
# [#f0066d 752MiB/1.7GiB(41%) CN:5 DL:15MiB ETA:1m6s]
# [#f0066d 766MiB/1.7GiB(42%) CN:5 DL:15MiB ETA:1m7s]
# [#f0066d 784MiB/1.7GiB(43%) CN:5 DL:15MiB ETA:1m4s]
# [#f0066d 806MiB/1.7GiB(44%) CN:5 DL:16MiB ETA:1m]
# [#f0066d 827MiB/1.7GiB(45%) CN:5 DL:17MiB ETA:57s]
# [#f0066d 843MiB/1.7GiB(46%) CN:5 DL:16MiB ETA:56s]
# [#f0066d 857MiB/1.7GiB(47%) CN:5 DL:16MiB ETA:58s]
# [#f0066d 871MiB/1.7GiB(48%) CN:5 DL:16MiB ETA:55s]
# [#f0066d 883MiB/1.7GiB(48%) CN:5 DL:16MiB ETA:56s]
# [#f0066d 897MiB/1.7GiB(49%) CN:5 DL:16MiB ETA:54s]
# [#f0066d 909MiB/1.7GiB(50%) CN:5 DL:15MiB ETA:57s]
# [#f0066d 0.9GiB/1.7GiB(50%) CN:5 DL:15MiB ETA:56s]
# [#f0066d 0.9GiB/1.7GiB(51%) CN:5 DL:15MiB ETA:58s]
# [#f0066d 0.9GiB/1.7GiB(52%) CN:5 DL:14MiB ETA:1m]
# [#f0066d 0.9GiB/1.7GiB(53%) CN:5 DL:13MiB ETA:1m2s]
# [#f0066d 0.9GiB/1.7GiB(54%) CN:5 DL:13MiB ETA:1m1s]
# [#f0066d 0.9GiB/1.7GiB(54%) CN:5 DL:13MiB ETA:1m]
# [#f0066d 0.9GiB/1.7GiB(56%) CN:5 DL:15MiB ETA:52s]
# [#f0066d 1.0GiB/1.7GiB(57%) CN:5 DL:15MiB ETA:50s]
# [#f0066d 1.0GiB/1.7GiB(57%) CN:5 DL:15MiB ETA:49s]
# [#f0066d 1.0GiB/1.7GiB(58%) CN:5 DL:15MiB ETA:47s]
# [#f0066d 1.0GiB/1.7GiB(59%) CN:5 DL:15MiB ETA:45s]
# [#f0066d 1.0GiB/1.7GiB(60%) CN:5 DL:16MiB ETA:44s]
# [#f0066d 1.0GiB/1.7GiB(61%) CN:5 DL:16MiB ETA:42s]
# [#f0066d 1.1GiB/1.7GiB(62%) CN:5 DL:16MiB ETA:41s]
# [#f0066d 1.1GiB/1.7GiB(63%) CN:5 DL:16MiB ETA:40s]
# [#f0066d 1.1GiB/1.7GiB(63%) CN:5 DL:16MiB ETA:40s]
# [#f0066d 1.1GiB/1.7GiB(64%) CN:5 DL:14MiB ETA:44s]
# [#f0066d 1.1GiB/1.7GiB(65%) CN:5 DL:14MiB ETA:44s]
# [#f0066d 1.1GiB/1.7GiB(65%) CN:5 DL:14MiB ETA:43s]
# [#f0066d 1.1GiB/1.7GiB(67%) CN:5 DL:14MiB ETA:39s]
# [#f0066d 1.2GiB/1.7GiB(68%) CN:5 DL:15MiB ETA:37s]
# [#f0066d 1.2GiB/1.7GiB(68%) CN:5 DL:15MiB ETA:37s]
# [#f0066d 1.2GiB/1.7GiB(69%) CN:5 DL:15MiB ETA:35s]
# [#f0066d 1.2GiB/1.7GiB(70%) CN:5 DL:15MiB ETA:33s]
# [#f0066d 1.2GiB/1.7GiB(72%) CN:5 DL:16MiB ETA:31s]
# [#f0066d 1.2GiB/1.7GiB(72%) CN:5 DL:16MiB ETA:30s]
# [#f0066d 1.2GiB/1.7GiB(73%) CN:5 DL:16MiB ETA:29s]
# [#f0066d 1.3GiB/1.7GiB(74%) CN:5 DL:16MiB ETA:28s]
# [#f0066d 1.3GiB/1.7GiB(74%) CN:5 DL:15MiB ETA:29s]
# [#f0066d 1.3GiB/1.7GiB(75%) CN:5 DL:14MiB ETA:30s]
# [#f0066d 1.3GiB/1.7GiB(77%) CN:5 DL:16MiB ETA:25s]
# [#f0066d 1.4GiB/1.7GiB(79%) CN:5 DL:19MiB ETA:18s]
# [#f0066d 1.4GiB/1.7GiB(82%) CN:5 DL:23MiB ETA:13s]
# [#f0066d 1.5GiB/1.7GiB(86%) CN:5 DL:27MiB ETA:9s]
# [#f0066d 1.5GiB/1.7GiB(88%) CN:5 DL:30MiB ETA:6s]
# [#f0066d 1.6GiB/1.7GiB(90%) CN:5 DL:33MiB ETA:4s]
# [#f0066d 1.6GiB/1.7GiB(92%) CN:5 DL:34MiB ETA:4s]
# [#f0066d 1.6GiB/1.7GiB(93%) CN:5 DL:35MiB ETA:3s]
# [#f0066d 1.6GiB/1.7GiB(93%) CN:5 DL:34MiB ETA:3s]
# [#f0066d 1.6GiB/1.7GiB(94%) CN:5 DL:34MiB ETA:3s]
# [#f0066d 1.6GiB/1.7GiB(94%) CN:5 DL:31MiB ETA:3s]
# [#f0066d 1.6GiB/1.7GiB(95%) CN:5 DL:26MiB ETA:3s]
# [#f0066d 1.7GiB/1.7GiB(96%) CN:5 DL:23MiB ETA:2s]
# [#f0066d 1.7GiB/1.7GiB(97%) CN:3 DL:20MiB ETA:2s]
#  *** Download Progress Summary as of Tue Sep 16 03:13:19 2025 ***
# ===============================================================================
# [#f0066d 1.7GiB/1.7GiB(97%) CN:3 DL:13MiB ETA:3s]
# FILE: phold_db/phold_search_db_v_1_0_0.tar.gz
# -------------------------------------------------------------------------------
#
# [#f0066d 1.7GiB/1.7GiB(97%) CN:3 DL:13MiB ETA:3s]
# [#f0066d 1.7GiB/1.7GiB(97%) CN:3 DL:11MiB ETA:3s]
# [#f0066d 1.7GiB/1.7GiB(97%) CN:3 DL:9.7MiB ETA:3s]
# [#f0066d 1.7GiB/1.7GiB(98%) CN:3 DL:9.3MiB ETA:3s]
# [#f0066d 1.7GiB/1.7GiB(98%) CN:3 DL:9.1MiB ETA:2s]
# [#f0066d 1.7GiB/1.7GiB(98%) CN:2 DL:8.4MiB ETA:2s]
# [#f0066d 1.7GiB/1.7GiB(99%) CN:2 DL:7.7MiB ETA:2s]
# [#f0066d 1.7GiB/1.7GiB(99%) CN:2 DL:6.5MiB ETA:2s]
# [#f0066d 1.7GiB/1.7GiB(99%) CN:1 DL:4.1MiB ETA:2s]
# [#f0066d 1.7GiB/1.7GiB(99%) CN:1 DL:3.7MiB ETA:3s]
# [#f0066d 1.7GiB/1.7GiB(99%) CN:1 DL:3.3MiB ETA:3s]
# [#f0066d 1.7GiB/1.7GiB(99%) CN:1 DL:3.0MiB ETA:3s]
# [#f0066d 1.7GiB/1.7GiB(99%) CN:1 DL:2.5MiB ETA:4s]
# [#f0066d 1.7GiB/1.7GiB(99%) CN:1 DL:2.0MiB ETA:3s]
# [#f0066d 1.7GiB/1.7GiB(99%) CN:1 DL:1.8MiB ETA:2s]
# [#f0066d 1.7GiB/1.7GiB(99%) CN:1 DL:1.7MiB ETA:1s]
#
# 09/16 03:13:35 [NOTICE] Download complete: phold_db/phold_search_db_v_1_0_0.tar.gz
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# f0066d|OK  |    12MiB/s|phold_db/phold_search_db_v_1_0_0.tar.gz
#
# Status Legend:
# (OK):download completed.
# 2025-09-16 03:13:35.701 | INFO     | phold.utils.external_tools:run_stream:72 - Done running aria2c --dir phold_db --out phold_search_db_v_1_0_0.tar.gz --max-connection-per-server=8 --allow-overwrite=true https://zenodo.org/records/16741548/files/phold_search_db_v_1_0_0.tar.gz
# 2025-09-16 03:13:40.232 | INFO     | phold.databases.db:install_database:174 - Phold database file download OK: ddbe0d94b1d94a392cfeb4ec113f4362
# 2025-09-16 03:13:40.232 | INFO     | phold.databases.db:install_database:180 - Extracting Phold database tarball: file=phold_db/phold_search_db_v_1_0_0.tar.gz, output=phold_db
# 2025-09-16 03:14:18.712 | INFO     | phold.databases.db:install_database:190 - Some Phold database files compatible with Foldseek-GPU are missing
# 2025-09-16 03:14:18.712 | INFO     | phold.databases.db:install_database:191 - Creating them
# 2025-09-16 03:14:18.713 | INFO     | phold.utils.external_tools:run:44 - Started running foldseek makepaddedseqdb phold_db/all_phold_structures phold_db/all_phold_structures_gpu ...
# 2025-09-16 03:14:49.710 | INFO     | phold.utils.external_tools:run:46 - Done running foldseek makepaddedseqdb phold_db/all_phold_structures phold_db/all_phold_structures_gpu
# Downloading phynteny database. This will take a few minutes. Please be patient :)
# /usr/local/lib/python3.12/site-packages/src/install_models.py:18: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# Creating 'models' subdirectory in specified path
# Downloading Phynteny models to: /content/phynteny_models/models
# 2025-09-16 03:14:58.006 | INFO     | src.install_models:instantiate_install:52 - Model installation directory (absolute path): /content/phynteny_models/models
# 2025-09-16 03:14:58.006 | WARNING  | src.install_models:check_db_installation:94 - Phynteny models are missing.
# 2025-09-16 03:14:58.006 | INFO     | src.install_models:instantiate_install:62 - Some models are missing.
# 2025-09-16 03:14:58.006 | INFO     | src.install_models:get_model_zenodo:326 - Models will be installed to: /content/phynteny_models/models
# 2025-09-16 03:14:58.007 | INFO     | src.install_models:get_model_zenodo:332 - Downloading tarball to: /content/phynteny_models
# 2025-09-16 03:14:58.007 | INFO     | src.install_models:get_model_zenodo:342 - Downloading Phynteny Models from https://zenodo.org/records/15584824/files/phynteny_transformer_models_2025-06-03.tar.gz.
# 2025-09-16 03:14:58.007 | DEBUG    | src.install_models:get_model_zenodo:343 - path
# 2025-09-16 03:14:58.007 | DEBUG    | src.install_models:get_model_zenodo:344 - https://zenodo.org/records/15584824/files/phynteny_transformer_models_2025-06-03.tar.gz
# 2025-09-16 03:14:58.587 | INFO     | src.install_models:download:115 - Downloading file, total size: 222.05 MB
# Progress: 100.0% (222.0/222.0 MB)
# 2025-09-16 03:16:07.642 | INFO     | src.install_models:get_model_zenodo:351 - Phynteny Models tarball download OK: 511358aca216d214b5d7ca7a57fe2250
# 2025-09-16 03:16:07.642 | INFO     | src.install_models:get_model_zenodo:358 - Extracting Phynteny Models tarball: file=phynteny_models/phynteny_transformer_models_2025-06-03.tar.gz, output=/content/phynteny_models/models
# 2025-09-16 03:16:07.642 | INFO     | src.install_models:untar:203 - Path checks: {'tarball_exists': True, 'tarball_readable': True, 'tarball_size': 232831570, 'output_exists': True, 'output_writable': True}
# 2025-09-16 03:16:09.959 | INFO     | src.install_models:untar:219 - Tarball inspection: {'status': 'success', 'file_count': 14, 'top_level_dirs': ['phynteny_transformer_models_2025-06-03'], 'sample_files': ['phynteny_transformer_models_2025-06-03', 'phynteny_transformer_models_2025-06-03/all_calibration_models.pkl', 'phynteny_transformer_models_2025-06-03/calibration_models.pkl', 'phynteny_transformer_models_2025-06-03/category_mapping.pkl', 'phynteny_transformer_models_2025-06-03/fold_10transformer.model']}
# 2025-09-16 03:16:09.960 | INFO     | src.install_models:untar:222 - Starting extraction: phynteny_models/phynteny_transformer_models_2025-06-03.tar.gz to phynteny_models/models
# 2025-09-16 03:16:12.703 | INFO     | src.install_models:untar:226 - Found 14 items in tarball
# 2025-09-16 03:16:12.703 | DEBUG    | src.install_models:untar:236 - Extracting: phynteny_transformer_models_2025-06-03
# 2025-09-16 03:16:12.704 | DEBUG    | src.install_models:untar:236 - Extracting: phynteny_transformer_models_2025-06-03/all_calibration_models.pkl
# 2025-09-16 03:16:12.709 | DEBUG    | src.install_models:untar:236 - Extracting: phynteny_transformer_models_2025-06-03/calibration_models.pkl
# 2025-09-16 03:16:12.710 | DEBUG    | src.install_models:untar:236 - Extracting: phynteny_transformer_models_2025-06-03/category_mapping.pkl
# 2025-09-16 03:16:12.711 | DEBUG    | src.install_models:untar:236 - Extracting: phynteny_transformer_models_2025-06-03/fold_10transformer.model
# 2025-09-16 03:16:12.993 | DEBUG    | src.install_models:untar:236 - Extracting: phynteny_transformer_models_2025-06-03/fold_1transformer.model
# 2025-09-16 03:16:13.231 | DEBUG    | src.install_models:untar:236 - Extracting: phynteny_transformer_models_2025-06-03/fold_2transformer.model
# 2025-09-16 03:16:13.460 | DEBUG    | src.install_models:untar:236 - Extracting: phynteny_transformer_models_2025-06-03/fold_3transformer.model
# 2025-09-16 03:16:13.753 | DEBUG    | src.install_models:untar:236 - Extracting: phynteny_transformer_models_2025-06-03/fold_4transformer.model
# 2025-09-16 03:16:13.977 | DEBUG    | src.install_models:untar:236 - Extracting: phynteny_transformer_models_2025-06-03/fold_5transformer.model
# 2025-09-16 03:16:14.205 | DEBUG    | src.install_models:untar:236 - Extracting: phynteny_transformer_models_2025-06-03/fold_6transformer.model
# 2025-09-16 03:16:14.447 | DEBUG    | src.install_models:untar:236 - Extracting: phynteny_transformer_models_2025-06-03/fold_7transformer.model
# 2025-09-16 03:16:14.695 | DEBUG    | src.install_models:untar:236 - Extracting: phynteny_transformer_models_2025-06-03/fold_8transformer.model
# 2025-09-16 03:16:14.957 | DEBUG    | src.install_models:untar:236 - Extracting: phynteny_transformer_models_2025-06-03/fold_9transformer.model
# 2025-09-16 03:16:15.205 | INFO     | src.install_models:untar:242 - Extraction completed
# 2025-09-16 03:16:15.205 | INFO     | src.install_models:untar:249 - Contents of output directory after extraction: ['phynteny_transformer_models_2025-06-03']
# 2025-09-16 03:16:15.205 | INFO     | src.install_models:untar:266 - Found potential model directories: ['phynteny_transformer_models_2025-06-03']
# 2025-09-16 03:16:15.206 | INFO     | src.install_models:untar:283 - Found 13 files to move from phynteny_models/models/phynteny_transformer_models_2025-06-03 to phynteny_models/models
# 2025-09-16 03:16:15.206 | DEBUG    | src.install_models:untar:289 - Moving phynteny_models/models/phynteny_transformer_models_2025-06-03/fold_8transformer.model to phynteny_models/models/fold_8transformer.model
# 2025-09-16 03:16:15.206 | DEBUG    | src.install_models:untar:289 - Moving phynteny_models/models/phynteny_transformer_models_2025-06-03/fold_7transformer.model to phynteny_models/models/fold_7transformer.model
# 2025-09-16 03:16:15.206 | DEBUG    | src.install_models:untar:289 - Moving phynteny_models/models/phynteny_transformer_models_2025-06-03/all_calibration_models.pkl to phynteny_models/models/all_calibration_models.pkl
# 2025-09-16 03:16:15.206 | DEBUG    | src.install_models:untar:289 - Moving phynteny_models/models/phynteny_transformer_models_2025-06-03/fold_2transformer.model to phynteny_models/models/fold_2transformer.model
# 2025-09-16 03:16:15.206 | DEBUG    | src.install_models:untar:289 - Moving phynteny_models/models/phynteny_transformer_models_2025-06-03/fold_4transformer.model to phynteny_models/models/fold_4transformer.model
# 2025-09-16 03:16:15.206 | DEBUG    | src.install_models:untar:289 - Moving phynteny_models/models/phynteny_transformer_models_2025-06-03/fold_1transformer.model to phynteny_models/models/fold_1transformer.model
# 2025-09-16 03:16:15.207 | DEBUG    | src.install_models:untar:289 - Moving phynteny_models/models/phynteny_transformer_models_2025-06-03/calibration_models.pkl to phynteny_models/models/calibration_models.pkl
# 2025-09-16 03:16:15.207 | DEBUG    | src.install_models:untar:289 - Moving phynteny_models/models/phynteny_transformer_models_2025-06-03/fold_6transformer.model to phynteny_models/models/fold_6transformer.model
# 2025-09-16 03:16:15.207 | DEBUG    | src.install_models:untar:289 - Moving phynteny_models/models/phynteny_transformer_models_2025-06-03/fold_5transformer.model to phynteny_models/models/fold_5transformer.model
# 2025-09-16 03:16:15.207 | DEBUG    | src.install_models:untar:289 - Moving phynteny_models/models/phynteny_transformer_models_2025-06-03/fold_9transformer.model to phynteny_models/models/fold_9transformer.model
# 2025-09-16 03:16:15.207 | DEBUG    | src.install_models:untar:289 - Moving phynteny_models/models/phynteny_transformer_models_2025-06-03/category_mapping.pkl to phynteny_models/models/category_mapping.pkl
# 2025-09-16 03:16:15.207 | DEBUG    | src.install_models:untar:289 - Moving phynteny_models/models/phynteny_transformer_models_2025-06-03/fold_3transformer.model to phynteny_models/models/fold_3transformer.model
# 2025-09-16 03:16:15.207 | DEBUG    | src.install_models:untar:289 - Moving phynteny_models/models/phynteny_transformer_models_2025-06-03/fold_10transformer.model to phynteny_models/models/fold_10transformer.model
# 2025-09-16 03:16:15.207 | INFO     | src.install_models:untar:296 - Successfully moved 13 files to phynteny_models/models
# 2025-09-16 03:16:15.207 | INFO     | src.install_models:untar:300 - Removing temporary directory: phynteny_models/models/phynteny_transformer_models_2025-06-03
# 2025-09-16 03:16:15.208 | INFO     | src.install_models:get_model_zenodo:364 - Keeping tarball at phynteny_models/phynteny_transformer_models_2025-06-03.tar.gz
# 2025-09-16 03:16:15.208 | INFO     | src.install_models:get_model_zenodo:368 - Installed 10 model files
# 2025-09-16 03:16:15.208 | INFO     | src.install_models:get_model_zenodo:373 - Done.
# 2025-09-16 03:16:15.208 | INFO     | src.install_models:instantiate_install:64 - Models successfully downloaded to: /content/phynteny_models/models
#
# Installation Summary:
# ---------------------
# Models directory: /content/phynteny_models/models
# Model files installed: 10
# Confidence dictionary: Missing
#
# When running phynteny_transformer, use:
#   phynteny_transformer -m /content/phynteny_models/models [other options] INPUT_FILE
# CPU times: user 2.65 s, sys: 705 ms, total: 3.35 s
# Wall time: 12min 38s

# %%
#@title 4. Run Pharokka

#@markdown First, upload your phage(s) as a nucleotide input FASTA file

#@markdown Click on the folder icon to the left and use the file upload button.

#@markdown Once it is uploaded, write the file name in the INPUT_FILE field on the right.

#@markdown Then provide a directory for pharokka's output using PHAROKKA_OUT_DIR.
#@markdown The default is 'output_pharokka'.

#@markdown Then type in a gene prediction tool for pharokka.
#@markdown Please choose either 'phanotate', 'prodigal', or 'prodigal-gv'.

#@markdown You can also provide a prefix for your output files with PHAROKKA_PREFIX.
#@markdown If you provide nothing it will default to 'pharokka'.

#@markdown You can also provide a locus tag for your output files.
#@markdown If you provide nothing it will generate a random locus tag.

#@markdown You can click FAST to turn off --fast.
#@markdown By default it is True so that Pharokka runs faster in the Colab environment.

#@markdown You can click META to turn on --meta if you have multiple phages in your input.

#@markdown You can click META_HMM to turn on --meta_hmm.

#@markdown You can click FORCE to overwrite the output directory.
#@markdown This may be useful if your earlier pharokka run has crashed for whatever reason.

#@markdown The results of Pharokka will be in the folder icon on the left hand panel.
#@markdown Additionally, it will be zipped so you can download the whole directory.

#@markdown The file to download is PHAROKKA_OUT_DIR.zip, where PHAROKKA_OUT_DIR is what you provided

#@markdown If you do not see the output directory,
#@markdown refresh the window by either clicking the folder with the refresh icon below "Files"
#@markdown or double click and select "Refresh".


# %%time
import os
import sys
import subprocess
import zipfile
INPUT_FILE = 'SAOMS1.fasta' #@param {type:"string"}

if os.path.exists(INPUT_FILE):
    print(f"Input file {INPUT_FILE} exists")
else:
    print(f"Error: File {INPUT_FILE} does not exist")
    print(f"Please check the spelling and that you have uploaded it correctly")
    sys.exit(1)

PHAROKKA_OUT_DIR = 'output_pharokka'  #@param {type:"string"}
GENE_PREDICTOR = 'phanotate'  #@param {type:"string"}
allowed_gene_predictors = ['phanotate', 'prodigal', 'prodigal-gv']
# Check if the input parameter is valid
if GENE_PREDICTOR.lower() not in allowed_gene_predictors:
    raise ValueError("Invalid GENE_PREDICTOR. Please choose from: 'phanotate', 'prodigal', 'prodigal-gv'.")

PHAROKKA_PREFIX = 'pharokka'  #@param {type:"string"}
LOCUS_TAG = 'Default'  #@param {type:"string"}
FAST = True  #@param {type:"boolean"}
META = False  #@param {type:"boolean"}
META_HMM = False  #@param {type:"boolean"}
FORCE = True  #@param {type:"boolean"}


# Construct the command
# need to suppress PYTHONWARNINGS for phanotate version handling
command = (
    f'pharokka.py -d pharokka_db -i {INPUT_FILE} -t 4 '
    f'-o {PHAROKKA_OUT_DIR} -p {PHAROKKA_PREFIX} -l {LOCUS_TAG} -g {GENE_PREDICTOR}'
)

if FORCE is True:
  command = f"{command} -f"

if FAST is True:
  command = f"{command} --fast"

if META is True:
  command = f"{command} -m"

if META_HMM is True:
  command = f"{command} --meta_hmm"

# Execute the command
try:
    print("Running pharokka")
    subprocess.run(command, shell=True, check=True)
    print("pharokka completed successfully.")
    print(f"Your output is in {PHAROKKA_OUT_DIR}.")
    print(f"Zipping the output directory so you can download it all in one go.")

    zip_filename = f"{PHAROKKA_OUT_DIR}.zip"

    # Zip the contents of the output directory
    with zipfile.ZipFile(zip_filename, 'w', zipfile.ZIP_DEFLATED) as zipf:
        for root, dirs, files in os.walk(PHAROKKA_OUT_DIR):
            for file in files:
                zipf.write(os.path.join(root, file), os.path.relpath(os.path.join(root, file), PHAROKKA_OUT_DIR))
    print(f"Output directory has been zipped to {zip_filename}")


except subprocess.CalledProcessError as e:
    print(f"Error occurred: {e}")
# Out:
# Input file SAOMS1.fasta exists
# Running pharokka
# pharokka completed successfully.
# Your output is in output_pharokka.
# Zipping the output directory so you can download it all in one go.
# Output directory has been zipped to output_pharokka.zip
# CPU times: user 163 ms, sys: 2.52 ms, total: 165 ms
# Wall time: 2min 10s

# %%
#@title 5. Run phold

#@markdown This cell will run phold on the output of cell 3's Pharokka run

#@markdown You do not need to provide any further input files

#@markdown You can now provide a directory for phold's output with PHOLD_OUT_DIR.
#@markdown The default is 'output_phold'.

#@markdown You can also provide a prefix for your output files with PHOLD_PREFIX.
#@markdown If you provide nothing it will default to 'phold'.

#@markdown You can click FORCE to overwrite the output directory with .
#@markdown This may be useful if your earlier phold run has crashed for whatever reason.

#@markdown If your input has multiple phages, you can click SEPARATE.
#@markdown This will output separate GenBank files in the output directory.

#@markdown The results of Phold will be in the folder icon on the left hand panel.
#@markdown Additionally, it will be zipped so you can download the whole directory.

#@markdown The file to download is PHOLD_OUT_DIR.zip, where PHOLD_OUT_DIR is what you provided

#@markdown If you do not see the output directory,
#@markdown refresh the window by either clicking the folder with the refresh icon below "Files"
#@markdown or double click and select "Refresh".


# %%time
import os
import subprocess
import zipfile

# phold input is pharokka output
PHOLD_INPUT = f"{PHAROKKA_OUT_DIR}/{PHAROKKA_PREFIX}.gbk"
PHOLD_OUT_DIR = 'output_phold'  #@param {type:"string"}
PHOLD_PREFIX = 'phold'  #@param {type:"string"}
FORCE = True  #@param {type:"boolean"}
SEPARATE = False  #@param {type:"boolean"}

# Construct the command
command = f"phold run -i {PHOLD_INPUT} -t 4 -o {PHOLD_OUT_DIR} -p {PHOLD_PREFIX} -d phold_db --foldseek_gpu"

if FORCE is True:
  command = f"{command} -f"
if SEPARATE is True:
  command = f"{command} --separate"


# Execute the command
try:
    print("Running phold")
    subprocess.run(command, shell=True, check=True)
    print("phold completed successfully.")
    print(f"Your output is in {PHOLD_OUT_DIR}.")
    print(f"Zipping the output directory so you can download it all in one go.")

    zip_filename = f"{PHOLD_OUT_DIR}.zip"

    # Zip the contents of the output directory
    with zipfile.ZipFile(zip_filename, 'w', zipfile.ZIP_DEFLATED) as zipf:
        for root, dirs, files in os.walk(PHOLD_OUT_DIR):
            for file in files:
                zipf.write(os.path.join(root, file), os.path.relpath(os.path.join(root, file), PHOLD_OUT_DIR))
    print(f"Output directory has been zipped to {zip_filename}")


except subprocess.CalledProcessError as e:
    print(f"Error occurred: {e}")
# Out:
# Running phold
# phold completed successfully.
# Your output is in output_phold.
# Zipping the output directory so you can download it all in one go.
# Output directory has been zipped to output_phold.zip
# CPU times: user 170 ms, sys: 4.29 ms, total: 175 ms
# Wall time: 2min 59s

# %%
#@title 6. Run Phynteny

#@markdown This cell will run phynteny on the output of cell 5's Phold run to predict the function of remaining hypothetical proteins

#@markdown You do not need to provide any further input files

#@markdown You can now provide a directory for phynteny's output with PHYNTENY_OUT_DIR.
#@markdown The default is 'output_phynteny'.

#@markdown You can click FORCE to overwrite the output directory with .
#@markdown This may be useful if your phynteny run has crashed for whatever reason.

#@markdown The results of Phynteny will be in the folder icon on the left hand panel.
#@markdown Additionally, it will be zipped so you can download the whole directory.

#@markdown The file to download is PHYNTENY_OUT_DIR.zip, where PHYNTENY_OUT_DIR is what you provided

#@markdown If you do not see the output directory,
#@markdown refresh the window by either clicking the folder with the refresh icon below "Files"
#@markdown or double click and select "Refresh".


# %%time
import os
import subprocess
import zipfile

# phynteny input is pharokka output
PHYNTENY_INPUT = f"{PHOLD_OUT_DIR}/{PHOLD_PREFIX}.gbk"
PHYNTENY_OUT_DIR = 'output_phynteny'  #@param {type:"string"}
FORCE = False  #@param {type:"boolean"}

# Construct the command
command = f"phynteny_transformer -m  /content/phynteny_models/models -o {PHYNTENY_OUT_DIR} {PHYNTENY_INPUT}"
if FORCE is True:
  command = f"{command} -f"


# Execute the command
try:
    print("Running phynteny")
    subprocess.run(command, shell=True, check=True)
    print("phynteny completed successfully.")
    print(f"Your output is in {PHYNTENY_OUT_DIR}.")
    print(f"Zipping the output directory so you can download it all in one go.")

    zip_filename = f"{PHYNTENY_OUT_DIR}.zip"

    # Zip the contents of the output directory
    with zipfile.ZipFile(zip_filename, 'w', zipfile.ZIP_DEFLATED) as zipf:
        for root, dirs, files in os.walk(PHYNTENY_OUT_DIR):
            for file in files:
                zipf.write(os.path.join(root, file), os.path.relpath(os.path.join(root, file), PHYNTENY_OUT_DIR))
    print(f"Output directory has been zipped to {zip_filename}")


except subprocess.CalledProcessError as e:
    print(f"Error occurred: {e}")
# Out:
# Running phynteny
# phynteny completed successfully.
# Your output is in output_phynteny.
# Zipping the output directory so you can download it all in one go.
# Output directory has been zipped to output_phynteny.zip
# CPU times: user 197 ms, sys: 3.98 ms, total: 201 ms
# Wall time: 1min 40s
